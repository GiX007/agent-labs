# %% [markdown]
# <a href="https://colab.research.google.com/github/GiX007/agent-labs/blob/main/05_crewAI/07_planning_estimation_allocation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # L1: Automated Project: Planning, Estimation, and Allocation

# %% [markdown]
# ## Initial Imports

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# Load environment variables
from helper import load_env
load_env()

import os
import yaml
from crewai import Agent, Task, Crew

# %% [markdown]
# ## Set OpenAI Model

# %%
os.environ['OPENAI_MODEL_NAME'] = 'gpt-4o-mini'

# %% [markdown]
# ## Loading Tasks and Agents YAML files

# %%
# Define file paths for YAML configurations
files = {
    'agents': 'config/agents.yaml',
    'tasks': 'config/tasks.yaml'
}

# Load configurations from YAML files
configs = {}
for config_type, file_path in files.items():
    with open(file_path, 'r') as file:
        configs[config_type] = yaml.safe_load(file)

# Assign loaded configurations to specific variables
agents_config = configs['agents']
tasks_config = configs['tasks']

# %% [markdown]
# ## Create Pydantic Models for Structured Output

# %%
from typing import List
from pydantic import BaseModel, Field

class TaskEstimate(BaseModel):
    task_name: str = Field(..., description="Name of the task")
    estimated_time_hours: float = Field(..., description="Estimated time to complete the task in hours")
    required_resources: List[str] = Field(..., description="List of resources required to complete the task")

class Milestone(BaseModel):
    milestone_name: str = Field(..., description="Name of the milestone")
    tasks: List[str] = Field(..., description="List of task IDs associated with this milestone")

class ProjectPlan(BaseModel):
    tasks: List[TaskEstimate] = Field(..., description="List of tasks with their estimates")
    milestones: List[Milestone] = Field(..., description="List of project milestones")

# %% [markdown]
# ## Create Crew, Agents and Tasks

# %%
# Creating Agents
project_planning_agent = Agent(
  config=agents_config['project_planning_agent']
)

estimation_agent = Agent(
  config=agents_config['estimation_agent']
)

resource_allocation_agent = Agent(
  config=agents_config['resource_allocation_agent']
)

# Creating Tasks
task_breakdown = Task(
  config=tasks_config['task_breakdown'],
  agent=project_planning_agent
)

time_resource_estimation = Task(
  config=tasks_config['time_resource_estimation'],
  agent=estimation_agent
)

resource_allocation = Task(
  config=tasks_config['resource_allocation'],
  agent=resource_allocation_agent,
  output_pydantic=ProjectPlan # This is the structured output we want
)

# Creating Crew
crew = Crew(
  agents=[
    project_planning_agent,
    estimation_agent,
    resource_allocation_agent
  ],
  tasks=[
    task_breakdown,
    time_resource_estimation,
    resource_allocation
  ],
  verbose=True
)

# %% [markdown]
# ## Crew's Inputs

# %%
from IPython.display import display, Markdown

project = 'Website'
industry = 'Technology'
project_objectives = 'Create a website for a small business'
team_members = """
- John Doe (Project Manager)
- Jane Doe (Software Engineer)
- Bob Smith (Designer)
- Alice Johnson (QA Engineer)
- Tom Brown (QA Engineer)
"""
project_requirements = """
- Create a responsive design that works well on desktop and mobile devices
- Implement a modern, visually appealing user interface with a clean look
- Develop a user-friendly navigation system with intuitive menu structure
- Include an "About Us" page highlighting the company's history and values
- Design a "Services" page showcasing the business's offerings with descriptions
- Create a "Contact Us" page with a form and integrated map for communication
- Implement a blog section for sharing industry news and company updates
- Ensure fast loading times and optimize for search engines (SEO)
- Integrate social media links and sharing capabilities
- Include a testimonials section to showcase customer feedback and build trust
"""

# Format the dictionary as Markdown for a better display in Jupyter Lab
formatted_output = f"""
**Project Type:** {project}

**Project Objectives:** {project_objectives}

**Industry:** {industry}

**Team Members:**
{team_members}
**Project Requirements:**
{project_requirements}
"""
# Display the formatted output as Markdown
display(Markdown(formatted_output))
# Out:
# **Project Type:** Website
#
# **Project Objectives:** Create a website for a small business
#
# **Industry:** Technology
#
# **Team Members:**
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
# **Project Requirements:**
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust

# %% [markdown]
# ## Kicking off the crew

# %%
# The given Python dictionary
inputs = {
  'project_type': project,
  'project_objectives': project_objectives,
  'industry': industry,
  'team_members': team_members,
  'project_requirements': project_requirements
}

# Run the crew
result = crew.kickoff(
  inputs=inputs
)
# Out:
# # Agent: The Ultimate Project Planner
# ## Task: Carefully analyze the project_requirements for the Website project and break them down into individual tasks. Define each task's scope in detail, set achievable timelines, and ensure that all dependencies are accounted for:
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust
#
#
# Team members:
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
#
#
#
# # Agent: The Ultimate Project Planner
# ## Final Answer:
# ### Comprehensive Breakdown of Website Project Tasks
#
# 1. **Create Responsive Design**
#    - **Description**: Design layouts adaptable to desktop and mobile screens using UX/UI principles.
#    - **Scope**: Analyze existing website designs and create wireframes. Use tools like Figma or Adobe XD for design prototyping.
#    - **Dependencies**: Requires initial approval from stakeholders.
#    - **Timeline**: 2 weeks (Start: Week 1, End: Week 2)
#    - **Deliverables**: Wireframes and design prototypes.
#
# 2. **Implement Modern User Interface**
#    - **Description**: Develop a visually appealing interface with clear typography, color scheme, and branding.
#    - **Scope**: Collaborate with designer to ensure branding consistency; utilize CSS frameworks like Bootstrap or Tailwind.
#    - **Dependencies**: Must wait for responsive design completion.
#    - **Timeline**: 3 weeks (Start: Week 3, End: Week 5)
#    - **Deliverables**: Finalized UI code.
#
# 3. **Develop Navigation System**
#    - **Description**: Create an intuitive menu structure for easy website navigation.
#    - **Scope**: Include dropdowns for services and a fixed navigation bar.
#    - **Dependencies**: Final UI design implementation must be complete.
#    - **Timeline**: 1 week (Start: Week 5, End: Week 6)
#    - **Deliverables**: Working navigation on webpage.
#
# 4. **Create "About Us" Page**
#    - **Description**: Draft and develop an "About Us" page that outlines the company history and values.
#    - **Scope**: Involve content team for copy and visuals.
#    - **Dependencies**: Should start after UI completion.
#    - **Timeline**: 1 week (Start: Week 6, End: Week 7)
#    - **Deliverables**: Live "About Us" page.
#
# 5. **Design "Services" Page**
#    - **Description**: Showcase services with engaging descriptions and images.
#    - **Scope**: Ensure SEO compliance and clear call-to-action buttons.
#    - **Dependencies**: Wait for the About Us page and navigation system.
#    - **Timeline**: 1 week (Start: Week 7, End: Week 8)
#    - **Deliverables**: Fully functional "Services" page.
#
# 6. **Create "Contact Us" Page**
#    - **Description**: Develop a form for inquiries and embed a Google map for physical location.
#    - **Scope**: Ensure backend integration for form submissions and test map functionality.
#    - **Dependencies**: Depends on Services page completion.
#    - **Timeline**: 1 week (Start: Week 8, End: Week 9)
#    - **Deliverables**: Operational "Contact Us" page with working form.
#
# 7. **Implement Blog Section**
#    - **Description**: Design and develop a blog section for company news and updates.
#    - **Scope**: Include features for admin to post articles, and categorize posts.
#    - **Dependencies**: Must have completed the "Services" page.
#    - **Timeline**: 2 weeks (Start: Week 9, End: Week 10)
#    - **Deliverables**: Live blog section.
#
# 8. **Ensure Fast Loading Times/SEO Optimization**
#    - **Description**: Optimize images, scripts, and other content to improve load times. Incorporate best SEO practices.
#    - **Scope**: Apply compression and caching strategies; use SEO tools for keyword optimization.
#    - **Dependencies**: Relevant content must already be in place.
#    - **Timeline**: 1 week (Start: Week 10, End: Week 11)
#    - **Deliverables**: Analytics report showing improved performance.
#
# 9. **Integrate Social Media Links**
#    - **Description**: Create clickable social media icons on the website footer and relevant pages.
#    - **Scope**: Ensure links open in new tabs and properly direct users to the respective sites.
#    - **Dependencies**: Requires completion of the main pages.
#    - **Timeline**: 1 week (Start: Week 11, End: Week 12)
#    - **Deliverables**: Implemented social media links.
#
# 10. **Include Testimonials Section**
#     - **Description**: Develop a testimonial carousel or section to display customer feedback.
#     - **Scope**: Involve content collection from previous clients and design an appealing context.
#     - **Dependencies**: Needs prior page completions.
#     - **Timeline**: 1 week (Start: Week 12, End: Week 13)
#     - **Deliverables**: Live testimonials section.
#
# ### Team Assignments:
# - **Project Manager**: John Doe - Oversees project timeline and deliverables.
# - **Software Engineer**: Jane Doe - Responsible for coding and backend integrations.
# - **Designer**: Bob Smith - Manages UI and UX designs.
# - **QA Engineer**: Alice Johnson - Conducts quality assurance checks.
# - **QA Engineer**: Tom Brown - Assists Alice in testing phases.
#
# ### Gantt Chart Timeline Visualization
#
# | Task                               | Start Week | Duration (Weeks) | End Week |
# |------------------------------------|------------|------------------|----------|
# | Create Responsive Design           | 1          | 2                | 2        |
# | Implement Modern User Interface     | 3          | 3                | 5        |
# | Develop Navigation System          | 5          | 1                | 6        |
# | Create "About Us" Page            | 6          | 1                | 7        |
# | Design "Services" Page            | 7          | 1                | 8        |
# | Create "Contact Us" Page          | 8          | 1                | 9        |
# | Implement Blog Section             | 9          | 2                | 10       |
# | Ensure Fast Loading Times/SEO      | 10         | 1                | 11       |
# | Integrate Social Media Links       | 11         | 1                | 12       |
# | Include Testimonials Section        | 12         | 1                | 13       |
#
# ### Summary
# The entire website project is designed to be completed in 13 weeks. Each task has been broken down meticulously into actionable portions with defined scopes, timelines, and deliverables. Dependencies have been accounted for to ensure smooth transitions from one task to another, minimizing the risk of delays. This structure sets a comprehensive roadmap for successfully delivering a small business website, ensuring quality and attractiveness that addresses user needs effectively.
#
# This project plan aligns teams with clear responsibilities while allowing room for efficiency improvements through continuous testing and QA processes.
#
#
# # Agent: Expert Estimation Analyst
# ## Task: Thoroughly evaluate each task in the Website project to estimate the time, resources, and effort required. Use historical data, task complexity, and available resources to provide a realistic estimation for each task.
#
#
#
# # Agent: Expert Estimation Analyst
# ## Final Answer:
# ### Detailed Estimation Report for Website Project
#
# #### 1. Create Responsive Design
# - **Time Required**: 2 weeks
# - **Resources**:
#   - Designer (Bob Smith)
#   - Tools: Figma or Adobe XD
# - **Effort Estimate**: 80 hours
# - **Risks/Uncertainties**: Delays due to stakeholder approval; potential need for rework based on feedback.
#
# #### 2. Implement Modern User Interface
# - **Time Required**: 3 weeks
# - **Resources**:
#   - Software Engineer (Jane Doe)
#   - Designer (Bob Smith) for collaboration
#   - CSS Frameworks: Bootstrap or Tailwind
# - **Effort Estimate**: 120 hours
# - **Risks/Uncertainties**: Issues with consistency in design or integration challenges with the backend.
#
# #### 3. Develop Navigation System
# - **Time Required**: 1 week
# - **Resources**:
#   - Software Engineer (Jane Doe)
# - **Effort Estimate**: 40 hours
# - **Risks/Uncertainties**: Potential oversight in navigational elements that might confuse users.
#
# #### 4. Create "About Us" Page
# - **Time Required**: 1 week
# - **Resources**:
#   - Software Engineer (Jane Doe)
#   - Content Team for copy
# - **Effort Estimate**: 40 hours
# - **Risks/Uncertainties**: Delays in content approval could hinder schedule.
#
# #### 5. Design "Services" Page
# - **Time Required**: 1 week
# - **Resources**:
#   - Software Engineer (Jane Doe)
#   - Content Team for visuals
# - **Effort Estimate**: 40 hours
# - **Risks/Uncertainties**: Ensuring SEO compliance may require additional time for testing.
#
# #### 6. Create "Contact Us" Page
# - **Time Required**: 1 week
# - **Resources**:
#   - Software Engineer (Jane Doe)
# - **Effort Estimate**: 40 hours
# - **Risks/Uncertainties**: Backend integration issues could arise, affecting functionality.
#
# #### 7. Implement Blog Section
# - **Time Required**: 2 weeks
# - **Resources**:
#   - Software Engineer (Jane Doe)
#   - Potential involvement from designer (Bob Smith)
# - **Effort Estimate**: 80 hours
# - **Risks/Uncertainties**: Future content management issues may complicate updates.
#
# #### 8. Ensure Fast Loading Times/SEO Optimization
# - **Time Required**: 1 week
# - **Resources**:
#   - Software Engineer (Jane Doe)
# - **Effort Estimate**: 40 hours
# - **Risks/Uncertainties**: May require continuous testing; SEO improvement might not meet organizational goals.
#
# #### 9. Integrate Social Media Links
# - **Time Required**: 1 week
# - **Resources**:
#   - Software Engineer (Jane Doe)
# - **Effort Estimate**: 40 hours
# - **Risks/Uncertainties**: Changes in social media policies could impact link functionality.
#
# #### 10. Include Testimonials Section
# - **Time Required**: 1 week
# - **Resources**:
#   - Software Engineer (Jane Doe)
#   - Content Management for collection of testimonials
# - **Effort Estimate**: 40 hours
# - **Risks/Uncertainties**: Collection delays from previous clients could affect timelines.
#
# ### Summary of Risks and Uncertainties
# - **Stakeholder Delays**: Approval of designs and content can lead to project delays.
# - **Integration Challenges**: New systems or tools may not provide compatibility, requiring additional time or adjustments.
# - **Content Management**: Relying on multiple teams for content may create scheduling conflicts or approval bottlenecks.
# - **Technical Uncertainties**: New technology or trends in UI/UX might emerge, causing shifts in project specifications.
#
# ### Conclusion
# The project is effectively structured to deliver outstanding results within a 13-week timeline. Each task has been carefully evaluated with a clear outline of resources, time, effort, and potential risks. This approach ensures that the website project stays on track, maximizing efficiency and quality while minimizing unexpected challenges.
#
# This detailed breakdown will facilitate precise project management, ensuring stakeholders are well-informed and teams can work cohesively towards a successful project delivery.
#
#
# # Agent: Resource Allocation Strategist
# ## Task: Strategically allocate tasks for the Website project to team members based on their skills, availability, and current workload. Ensure that each task is assigned to the most suitable team member and that the workload is evenly distributed.
#
# Team members:
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
# # Agent: Resource Allocation Strategist
# ## Final Answer:
# ### Resource Allocation Chart for Website Project
#
# | Task                            | Team Member(s)                  | Start Date  | End Date    | Estimated Hours  |
# |---------------------------------|----------------------------------|-------------|-------------|------------------|
# | Create Responsive Design        | Bob Smith (Designer)            | Week 1     | Week 2     | 80               |
# | Implement Modern User Interface  | Jane Doe (Software Engineer), Bob Smith (Designer) | Week 3 | Week 5     | 120              |
# | Develop Navigation System       | Jane Doe (Software Engineer)    | Week 6     | Week 6     | 40               |
# | Create "About Us" Page         | Jane Doe (Software Engineer)    | Week 6     | Week 6     | 40               |
# | Design "Services" Page         | Jane Doe (Software Engineer)    | Week 7     | Week 7     | 40               |
# | Create "Contact Us" Page       | Jane Doe (Software Engineer)    | Week 7     | Week 7     | 40               |
# | Implement Blog Section          | Jane Doe (Software Engineer), Bob Smith (Designer) | Week 8 | Week 9     | 80               |
# | Ensure Fast Loading Times/SEO Optimization | Jane Doe (Software Engineer) | Week 9 | Week 9     | 40               |
# | Integrate Social Media Links    | Jane Doe (Software Engineer)    | Week 10    | Week 10    | 40               |
# | Include Testimonials Section     | Jane Doe (Software Engineer)    | Week 10    | Week 10    | 40               |
#
# ### Summary and Rationale for Task Allocation
#
# 1. **Create Responsive Design**: Bob Smith is assigned this task as he is the Designer. His expertise ensures the design is visually appealing and accessible across various devices. The task duration is set for 2 weeks to allow for stakeholder feedback and potential revisions.
#
# 2. **Implement Modern User Interface**: Jane Doe, being the Software Engineer, is the best fit for the implementation of a user interface. Collaborating with Bob Smith will ensure the design and technical aspects align. This task requires 3 weeks to account for collaborative efforts and integration challenges.
#
# 3. **Develop Navigation System**: This task, involving a straightforward execution that Jane can handle, is allocated for 1 week, ensuring quick turnaround.
#
# 4. **Create "About Us" Page**: Jane is designated for this task as well since it requires her coding expertise to build the structure while also needing close communication with the content team. This task also fits into Week 6, aligning with content approval timelines.
#
# 5. **Design "Services" Page** and **Create "Contact Us" Page**: Both tasks are similar in that they require Jane’s contribution as a Software Engineer. They can conveniently take place in Week 7, allowing her to work efficiently on multiple pages within a tight timeframe.
#
# 6. **Implement Blog Section**: This task is labor-intensive and requires collaborative input from both Jane and Bob, using their respective skills in software engineering and design over a 2-week period.
#
# 7. **Ensure Fast Loading Times/SEO Optimization**: Jane has a solid understanding of performance aspects, making her the ideal candidate for this task, which should be completed within a week as it allows for adjustments after testing.
#
# 8. **Integrate Social Media Links** and **Include Testimonials Section**: Both tasks are allocated a week each, heavily reliant on Jane’s programming skills, while the latter may require content team coordination for testimonial collection.
#
# This allocation ensures that the project leverages the unique skills of each team member while balancing their workloads, thus maximizing productivity without overburdening anyone. The timeline reflects a strategic approach that considers potential risks and uncertainties, ensuring project success delivered efficiently within the 13-week framework.

# %% [markdown]
# ## Usage Metrics and Costs

# %% [markdown]
# Let’s see how much it would cost each time if this crew runs at scale.

# %%
import pandas as pd

costs = 0.150 * (crew.usage_metrics.prompt_tokens + crew.usage_metrics.completion_tokens) / 1_000_000
print(f"Total costs: ${costs:.4f}")

# Convert UsageMetrics instance to a DataFrame
df_usage_metrics = pd.DataFrame([crew.usage_metrics.dict()])
df_usage_metrics
# Out:
# Total costs: $0.0027
#    total_tokens  prompt_tokens  completion_tokens  successful_requests
# 0         17683          10907               6776                    9

# %% [markdown]
# ## Result

# %%
result.pydantic.dict()
# Out:
# {'tasks': [{'task_name': 'Create Responsive Design',
#    'estimated_time_hours': 80.0,
#    'required_resources': ['Bob Smith (Designer)']},
#   {'task_name': 'Implement Modern User Interface',
#    'estimated_time_hours': 120.0,
#    'required_resources': ['Jane Doe (Software Engineer)',
#     'Bob Smith (Designer)']},
#   {'task_name': 'Develop Navigation System',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe (Software Engineer)']},
#   {'task_name': 'Create "About Us" Page',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe (Software Engineer)']},
#   {'task_name': 'Design "Services" Page',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe (Software Engineer)']},
#   {'task_name': 'Create "Contact Us" Page',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe (Software Engineer)']},
#   {'task_name': 'Implement Blog Section',
#    'estimated_time_hours': 80.0,
#    'required_resources': ['Jane Doe (Software Engineer)',
#     'Bob Smith (Designer)']},
#   {'task_name': 'Ensure Fast Loading Times/SEO Optimization',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe (Software Engineer)']},
#   {'task_name': 'Integrate Social Media Links',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe (Software Engineer)']},
#   {'task_name': 'Include Testimonials Section',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe (Software Engineer)']}],
#  'milestones': [{'milestone_name': 'Design Phase Completion',
#    'tasks': ['Create Responsive Design', 'Implement Modern User Interface']},
#   {'milestone_name': 'Development Phase Completion',
#    'tasks': ['Develop Navigation System',
#     'Create "About Us" Page',
#     'Design "Services" Page',
#     'Create "Contact Us" Page',
#     'Implement Blog Section']},
#   {'milestone_name': 'Optimization and Final Touches',
#    'tasks': ['Ensure Fast Loading Times/SEO Optimization',
#     'Integrate Social Media Links',
#     'Include Testimonials Section']}]}

# %% [markdown]
# ## Inspect further

# %%
tasks = result.pydantic.dict()['tasks']
df_tasks = pd.DataFrame(tasks)

# Display the DataFrame as an HTML table
df_tasks.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# <style type="text/css">
# #T_13647 th {
#   font-size: 120%;
# }
# #T_13647  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_13647" border="1">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_13647_level0_col0" class="col_heading level0 col0" >task_name</th>
#       <th id="T_13647_level0_col1" class="col_heading level0 col1" >estimated_time_hours</th>
#       <th id="T_13647_level0_col2" class="col_heading level0 col2" >required_resources</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_13647_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_13647_row0_col0" class="data row0 col0" >Create Responsive Design</td>
#       <td id="T_13647_row0_col1" class="data row0 col1" >80.000000</td>
#       <td id="T_13647_row0_col2" class="data row0 col2" >['Bob Smith (Designer)']</td>
#     </tr>
#     <tr>
#       <th id="T_13647_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_13647_row1_col0" class="data row1 col0" >Implement Modern User Interface</td>
#       <td id="T_13647_row1_col1" class="data row1 col1" >120.000000</td>
#       <td id="T_13647_row1_col2" class="data row1 col2" >['Jane Doe (Software Engineer)', 'Bob Smith (Designer)']</td>
#     </tr>
#     <tr>
#       <th id="T_13647_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_13647_row2_col0" class="data row2 col0" >Develop Navigation System</td>
#       <td id="T_13647_row2_col1" class="data row2 col1" >40.000000</td>
#       <td id="T_13647_row2_col2" class="data row2 col2" >['Jane Doe (Software Engineer)']</td>
#     </tr>
#     <tr>
#       <th id="T_13647_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_13647_row3_col0" class="data row3 col0" >Create "About Us" Page</td>
#       <td id="T_13647_row3_col1" class="data row3 col1" >40.000000</td>
#       <td id="T_13647_row3_col2" class="data row3 col2" >['Jane Doe (Software Engineer)']</td>
#     </tr>
#     <tr>
#       <th id="T_13647_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_13647_row4_col0" class="data row4 col0" >Design "Services" Page</td>
#       <td id="T_13647_row4_col1" class="data row4 col1" >40.000000</td>
#       <td id="T_13647_row4_col2" class="data row4 col2" >['Jane Doe (Software Engineer)']</td>
#     </tr>
#     <tr>
#       <th id="T_13647_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_13647_row5_col0" class="data row5 col0" >Create "Contact Us" Page</td>
#       <td id="T_13647_row5_col1" class="data row5 col1" >40.000000</td>
#       <td id="T_13647_row5_col2" class="data row5 col2" >['Jane Doe (Software Engineer)']</td>
#     </tr>
#     <tr>
#       <th id="T_13647_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_13647_row6_col0" class="data row6 col0" >Implement Blog Section</td>
#       <td id="T_13647_row6_col1" class="data row6 col1" >80.000000</td>
#       <td id="T_13647_row6_col2" class="data row6 col2" >['Jane Doe (Software Engineer)', 'Bob Smith (Designer)']</td>
#     </tr>
#     <tr>
#       <th id="T_13647_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_13647_row7_col0" class="data row7 col0" >Ensure Fast Loading Times/SEO Optimization</td>
#       <td id="T_13647_row7_col1" class="data row7 col1" >40.000000</td>
#       <td id="T_13647_row7_col2" class="data row7 col2" >['Jane Doe (Software Engineer)']</td>
#     </tr>
#     <tr>
#       <th id="T_13647_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_13647_row8_col0" class="data row8 col0" >Integrate Social Media Links</td>
#       <td id="T_13647_row8_col1" class="data row8 col1" >40.000000</td>
#       <td id="T_13647_row8_col2" class="data row8 col2" >['Jane Doe (Software Engineer)']</td>
#     </tr>
#     <tr>
#       <th id="T_13647_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_13647_row9_col0" class="data row9 col0" >Include Testimonials Section</td>
#       <td id="T_13647_row9_col1" class="data row9 col1" >40.000000</td>
#       <td id="T_13647_row9_col2" class="data row9 col2" >['Jane Doe (Software Engineer)']</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Inspecting Milestones

# %%
milestones = result.pydantic.dict()['milestones']
df_milestones = pd.DataFrame(milestones)

# Display the DataFrame as an HTML table
df_milestones.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# <style type="text/css">
# #T_db34d th {
#   font-size: 120%;
# }
# #T_db34d  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_db34d" border="1">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_db34d_level0_col0" class="col_heading level0 col0" >milestone_name</th>
#       <th id="T_db34d_level0_col1" class="col_heading level0 col1" >tasks</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_db34d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_db34d_row0_col0" class="data row0 col0" >Design Phase Completion</td>
#       <td id="T_db34d_row0_col1" class="data row0 col1" >['Create Responsive Design', 'Implement Modern User Interface']</td>
#     </tr>
#     <tr>
#       <th id="T_db34d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_db34d_row1_col0" class="data row1 col0" >Development Phase Completion</td>
#       <td id="T_db34d_row1_col1" class="data row1 col1" >['Develop Navigation System', 'Create "About Us" Page', 'Design "Services" Page', 'Create "Contact Us" Page', 'Implement Blog Section']</td>
#     </tr>
#     <tr>
#       <th id="T_db34d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_db34d_row2_col0" class="data row2 col0" >Optimization and Final Touches</td>
#       <td id="T_db34d_row2_col1" class="data row2 col1" >['Ensure Fast Loading Times/SEO Optimization', 'Integrate Social Media Links', 'Include Testimonials Section']</td>
#     </tr>
#   </tbody>
# </table>
