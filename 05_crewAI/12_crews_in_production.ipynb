# %% [markdown]
# <a href="https://colab.research.google.com/github/GiX007/agent-labs/blob/main/05_crewAI/12_crews_in_production.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # L6: Building Your Crew for Production

# %% [markdown]
# ## Initial Imports

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# Load environment variables
from helper import load_env
load_env()

# %% [markdown]
# ## Creating a new project

# %%
! crewai create crew new_project --provider openai
# Out:
# Creating folder new_project...
#   - Created new_project/.gitignore
#   - Created new_project/pyproject.toml
#   - Created new_project/README.md
#   - Created new_project/src/new_project/__init__.py
#   - Created new_project/src/new_project/main.py
#   - Created new_project/src/new_project/crew.py
#   - Created new_project/src/new_project/tools/custom_tool.py
#   - Created new_project/src/new_project/tools/__init__.py
#   - Created new_project/src/new_project/config/agents.yaml
#   - Created new_project/src/new_project/config/tasks.yaml
# Crew new_project created successfully!

# %% [markdown]
# ## Setting up the Environment

# %%
! cd new_project && crewai install
# Out:
# Using CPython 3.11.9 interpreter at: /usr/local/bin/python
# Creating virtual environment at: .venv
# Resolved 179 packages in 1.91s
# Building new-project @ file:///home/jovyan/work/L13/new_project
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/174)
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/174)
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/174)
# cryptography ------------------------------     0 B/4.27 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/174)
# hf-xet     ------------------------------     0 B/3.17 MiB
# cryptography ------------------------------     0 B/4.27 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/174)
# pydantic-core ------------------------------     0 B/1.97 MiB
# hf-xet     ------------------------------     0 B/3.17 MiB
# cryptography ------------------------------     0 B/4.27 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/174)
# pygments   ------------------------------     0 B/1.17 MiB
# pydantic-core ------------------------------     0 B/1.97 MiB
# hf-xet     ------------------------------     0 B/3.17 MiB
# cryptography ------------------------------     0 B/4.27 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/174)
# pyyaml     ------------------------------     0 B/787.73 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# pydantic-core ------------------------------     0 B/1.97 MiB
# hf-xet     ------------------------------     0 B/3.17 MiB
# cryptography ------------------------------     0 B/4.27 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/174)
# mpmath     ------------------------------     0 B/523.63 KiB
# pyyaml     ------------------------------     0 B/787.73 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# pydantic-core ------------------------------     0 B/1.97 MiB
# hf-xet     ------------------------------     0 B/3.17 MiB
# cryptography ------------------------------     0 B/4.27 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/174)
# distlib    ------------------------------     0 B/458.05 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# pyyaml     ------------------------------     0 B/787.73 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# pydantic-core ------------------------------     0 B/1.97 MiB
# hf-xet     ------------------------------     0 B/3.17 MiB
# cryptography ------------------------------     0 B/4.27 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/174)
# pydantic   ------------------------------     0 B/452.71 KiB
# distlib    ------------------------------     0 B/458.05 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# pyyaml     ------------------------------     0 B/787.73 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# pydantic-core ------------------------------     0 B/1.97 MiB
# hf-xet     ------------------------------     0 B/3.17 MiB
# cryptography ------------------------------     0 B/4.27 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/174)
# google-genai ------------------------------     0 B/416.57 KiB
# pydantic   ------------------------------     0 B/452.71 KiB
# distlib    ------------------------------     0 B/458.05 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# pyyaml     ------------------------------     0 B/787.73 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# pydantic-core ------------------------------     0 B/1.97 MiB
# hf-xet     ------------------------------     0 B/3.17 MiB
# cryptography ------------------------------     0 B/4.27 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/174)
# rpds-py    ------------------------------     0 B/381.67 KiB
# google-genai ------------------------------     0 B/416.57 KiB
# pydantic   ------------------------------     0 B/452.71 KiB
# distlib    ------------------------------     0 B/458.05 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# pyyaml     ------------------------------     0 B/787.73 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# pydantic-core ------------------------------     0 B/1.97 MiB
# hf-xet     ------------------------------     0 B/3.17 MiB
# cryptography ------------------------------     0 B/4.27 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/174)
# rpds-py    ------------------------------     0 B/381.67 KiB
# prompt-toolkit ------------------------------     0 B/382.26 KiB
# google-genai ------------------------------     0 B/416.57 KiB
# pydantic   ------------------------------     0 B/452.71 KiB
# distlib    ------------------------------     0 B/458.05 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# pyyaml     ------------------------------     0 B/787.73 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# pydantic-core ------------------------------     0 B/1.97 MiB
# hf-xet     ------------------------------     0 B/3.17 MiB
# cryptography ------------------------------     0 B/4.27 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/174)
# anthropic  ------------------------------     0 B/379.07 KiB
# rpds-py    ------------------------------     0 B/381.67 KiB
# prompt-toolkit ------------------------------     0 B/382.26 KiB
# google-genai ------------------------------     0 B/416.57 KiB
# pydantic   ------------------------------     0 B/452.71 KiB
# distlib    ------------------------------     0 B/458.05 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# pyyaml     ------------------------------     0 B/787.73 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# pydantic-core ------------------------------     0 B/1.97 MiB
# hf-xet     ------------------------------     0 B/3.17 MiB
# cryptography ------------------------------     0 B/4.27 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/174)
# jiter      ------------------------------     0 B/350.75 KiB
# anthropic  ------------------------------     0 B/379.07 KiB
# rpds-py    ------------------------------     0 B/381.67 KiB
# prompt-toolkit ------------------------------     0 B/382.26 KiB
# google-genai ------------------------------     0 B/416.57 KiB
# pydantic   ------------------------------     0 B/452.71 KiB
# distlib    ------------------------------     0 B/458.05 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# pyyaml     ------------------------------     0 B/787.73 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# pydantic-core ------------------------------     0 B/1.97 MiB
# hf-xet     ------------------------------     0 B/3.17 MiB
# cryptography ------------------------------     0 B/4.27 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/174)
# pypdf      ------------------------------     0 B/321.84 KiB
# jiter      ------------------------------     0 B/350.75 KiB
# anthropic  ------------------------------     0 B/379.07 KiB
# rpds-py    ------------------------------     0 B/381.67 KiB
# prompt-toolkit ------------------------------     0 B/382.26 KiB
# google-genai ------------------------------     0 B/416.57 KiB
# pydantic   ------------------------------     0 B/452.71 KiB
# distlib    ------------------------------     0 B/458.05 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# pyyaml     ------------------------------     0 B/787.73 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# pydantic-core ------------------------------     0 B/1.97 MiB
# hf-xet     ------------------------------     0 B/3.17 MiB
# cryptography ------------------------------     0 B/4.27 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/174)
# protobuf   ------------------------------ 62.92 KiB/315.69 KiB
# pypdf      ------------------------------ 62.89 KiB/321.84 KiB
# jiter      ------------------------------ 61.43 KiB/350.75 KiB
# yarl       ------------------------------ 16.00 KiB/357.25 KiB
# anthropic  ------------------------------ 30.92 KiB/379.07 KiB
# rpds-py    ------------------------------ 62.92 KiB/381.67 KiB
# prompt-toolkit ------------------------------ 24.77 KiB/382.26 KiB
# google-genai ------------------------------ 30.88 KiB/416.57 KiB
# watchfiles ------------------------------ 16.00 KiB/445.39 KiB
# httptools  ------------------------------ 16.00 KiB/445.92 KiB
# pydantic   ------------------------------ 30.78 KiB/452.71 KiB
# distlib    ------------------------------ 46.78 KiB/458.05 KiB
# crewai     ------------------------------ 30.85 KiB/462.12 KiB
# youtube-transcript-api ------------------------------
ms
#  + aiohappyeyeballs==2.6.1
#  + aiohttp==3.13.2
#  + aiosignal==1.4.0
#  + annotated-types==0.7.0
#  + anthropic==0.75.0
#  + anyio==4.12.0
#  + appdirs==1.4.4
#  + asttokens==3.0.1
#  + attrs==25.4.0
#  + backoff==2.2.1
#  + bcrypt==5.0.0
#  + beautifulsoup4==4.14.3
#  + blinker==1.9.0
#  + browserbase==1.4.0
#  + build==1.3.0
#  + cachetools==6.2.4
#  + certifi==2025.11.12
#  + cffi==2.0.0
#  + cfgv==3.5.0
#  + charset-normalizer==3.4.4
#  + chromadb==1.1.1
#  + click==8.3.1
#  + coloredlogs==15.0.1
#  + crewai==0.203.2
#  + crewai-tools==0.76.0
#  + cryptography==46.0.3
#  + decorator==5.2.1
#  + defusedxml==0.7.1
#  + deprecation==2.1.0
#  + diskcache==5.6.3
#  + distlib==0.4.0
#  + distro==1.9.0
#  + docker==7.1.0
#  + docstring-parser==0.17.0
#  + durationpy==0.10
#  + et-xmlfile==2.0.0
#  + executing==2.2.1
#  + filelock==3.20.1
#  + flatbuffers==25.12.19
#  + frozenlist==1.8.0
#  + fsspec==2025.12.0
#  + google-auth==2.45.0
#  + google-genai==1.56.0
#  + googleapis-common-protos==1.72.0
#  + greenlet==3.3.0
#  + grpcio==1.76.0
#  + h11==0.16.0
#  + hf-xet==1.2.0
#  + httpcore==1.0.9
#  + httptools==0.7.1
#  + httpx==0.28.1
#  + huggingface-hub==1.2.3
#  + humanfriendly==10.0
#  + identify==2.6.15
#  + idna==3.11
#  + importlib-metadata==8.7.1
#  + importlib-resources==6.5.2
#  + instructor==1.13.0
#  + ipython==8.37.0
#  + jedi==0.19.2
#  + jinja2==3.1.6
#  + jiter==0.11.1
#  + json-repair==0.25.2
#  + json5==0.12.1
#  + jsonpickle==4.1.1
#  + jsonref==1.1.0
#  + jsonschema==4.25.1
#  + jsonschema-specifications==2025.9.1
#  + kubernetes==34.1.0
#  + lance-namespace==0.3.2
#  + lance-namespace-urllib3-client==0.3.2
#  + lancedb==0.26.0
#  + litellm==1.74.9
#  + lxml==6.0.2
#  + markdown-it-py==4.0.0
#  + markupsafe==3.0.3
#  + matplotlib-inline==0.2.1
#  + mdurl==0.1.2
#  + mmh3==5.2.0
#  + mpmath==1.3.0
#  + multidict==6.7.0
#  + nest-asyncio==1.6.0
#  + networkx==3.4.2
#  + new-project==0.1.0 (from file:///home/jovyan/work/L13/new_project)
#  + nodeenv==1.10.0
#  + numpy==2.2.6
#  + oauthlib==3.3.1
#  + onnxruntime==1.23.2
#  + openai==2.14.0
#  + openpyxl==3.1.5
#  + opentelemetry-api==1.39.1
#  + opentelemetry-exporter-otlp-proto-common==1.39.1
#  + opentelemetry-exporter-otlp-proto-grpc==1.39.1
#  + opentelemetry-exporter-otlp-proto-http==1.39.1
#  + opentelemetry-proto==1.39.1
#  + opentelemetry-sdk==1.39.1
#  + opentelemetry-semantic-conventions==0.60b1
#  + orjson==3.11.5
#  + overrides==7.7.0
#  + packaging==25.0
#  + parso==0.8.5
#  + pdfminer-six==20251107
#  + pdfplumber==0.11.8
#  + pexpect==4.9.0
#  + pillow==12.0.0
#  + platformdirs==4.5.1
#  + playwright==1.57.0
#  + portalocker==2.7.0
#  + posthog==5.4.0
#  + pre-commit==4.5.1
#  + prompt-toolkit==3.0.52
#  + propcache==0.4.1
#  + protobuf==6.33.2
#  + ptyprocess==0.7.0
#  + pure-eval==0.2.3
#  + pyarrow==22.0.0
#  + pyasn1==0.6.1
#  + pyasn1-modules==0.4.2
#  + pybase64==1.4.3
#  + pycparser==2.23
#  + pydantic==2.12.5
#  + pydantic-core==2.41.5
#  + pydantic-settings==2.12.0
#  + pyee==13.0.0
#  + pygments==2.19.2
#  + pyjwt==2.10.1
#  + pypdf==6.5.0
#  + pypdfium2==5.2.0
#  + pypika==0.48.9
#  + pyproject-hooks==1.2.0
#  + python-dateutil==2.9.0.post0
#  + python-docx==1.2.0
#  + python-dotenv==1.2.1
#  + pytube==15.0.0
#  + pyvis==0.3.2
#  + pyyaml==6.0.3
#  + referencing==0.37.0
#  + regex==2025.11.3
#  + requests==2.32.5
#  + requests-oauthlib==2.0.0
#  + rich==14.2.0
#  + rpds-py==0.30.0
#  + rsa==4.9.1
#  + shellingham==1.5.4
#  + six==1.17.0
#  + sniffio==1.3.1
#  + soupsieve==2.8.1
#  + stack-data==0.6.3
#  + stagehand==0.5.8
#  + sympy==1.14.0
#  + tenacity==9.1.2
#  + tiktoken==0.12.0
#  + tokenizers==0.22.1
#  + tomli==2.3.0
#  + tomli-w==1.2.0
#  + tqdm==4.67.1
#  + traitlets==5.14.3
#  + ty==0.0.5
#  + typer==0.20.1
#  + typer-slim==0.20.1
#  + typing-extensions==4.15.0
#  + typing-inspection==0.4.2
#  + urllib3==2.3.0
#  + uv==0.9.18
#  + uvicorn==0.40.0
#  + uvloop==0.22.1
#  + virtualenv==20.35.4
#  + watchfiles==1.1.1
#  + wcwidth==0.2.14
#  + websocket-client==1.9.0
#  + websockets==15.0.1
#  + yarl==1.22.0
#  + youtube-transcript-api==1.2.3
#  + zipp==3.23.0

# %% [markdown]
# ## Setting Environment Variables

# %%
! cat new_project/.env
# Out:
# OPENAI_API_KEY=YOUR_API_KEY_HERE

# %% [markdown]
# ## Running the Crew

# %%
! cd new_project && crewai run
# Out:
# Running the Crew
# ╭─────────────────────────── Crew Execution Started ───────────────────────────╮
# │                                                                              │
# │  Crew Execution Started                                                      │
# │  Name: crew                                                                  │
# │  ID: fcab55cc-1ed8-4841-95c0-58bd668e4185                                    │
# │  Tool Args:                                                                  │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# 🚀 Crew: crew
# └── 📋 Task: research_task (ID: a6e24e38-a307-45c8-8e28-55624b7d4b4b)
#     Status: Executing Task...
# ╭────────────────────────────── 🤖 Agent Started ──────────────────────────────╮
# │                                                                              │
# │  Agent: AI LLMs Senior Data Researcher                                       │
# │                                                                              │
# │  Task: Conduct a thorough research about AI LLMs Make sure you find any      │
# │  interesting and relevant information given the current year is 2024.        │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# 🚀 Crew: crew
# └── 📋 Task: research_task (ID: a6e24e38-a307-45c8-8e28-55624b7d4b4b)
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: research_task (ID: a6e24e38-a307-45c8-8e28-55624b7d4b4b)
# 🚀 Crew: crew
# └── 📋 Task: research_task (ID: a6e24e38-a307-45c8-8e28-55624b7d4b4b)
#     Status: Executing Task...
# ╭─────────────────────────── ✅ Agent Final Answer ────────────────────────────╮
# │                                                                              │
# │  Agent: AI LLMs Senior Data Researcher                                       │
# │                                                                              │
# │  Final Answer:                                                               │
# │  1. **Scaling Laws:** Researchers continue to confirm the scaling laws for   │
# │  LLMs, illustrating that as model size and training data increase,           │
# │  performance improves consistently. This has led to ongoing advancements in  │
# │  developing larger and more capable models.                                  │
# │                                                                              │
# │  2. **Multimodal LLMs:** The emergence of multimodal LLMs, which can         │
# │  process and generate text, images, and other forms of data, is becoming     │
# │  prominent. Models like OpenAI's DALL-E and Google's PaLM demonstrate how    │
# │  integrating different modalities enhances creative capabilities.            │
# │                                                                              │
# │  3. **Fine-tuning Techniques:** Innovative fine-tuning methods such as       │
# │  adapter tuning and prompt tuning are being increasingly utilized, allowing  │
# │  for more efficient model adaptation to specific tasks without extensive     │
# │  retraining from scratch.                                                    │
# │                                                                              │
# │  4. **Ethical AI and Bias Mitigation:** Significant efforts are being made   │
# │  to address biases in AI LLMs. New frameworks and tools are being developed  │
# │  to detect and mitigate biases in model outputs, ensuring fairer and more    │
# │  ethical use of LLMs across various applications.                            │
# │                                                                              │
# │  5. **Energy Efficiency:** Researchers are focusing on making evaluations    │
# │  of LLMs more energy-efficient, contributing to sustainability in AI         │
# │  development. Techniques such as quantization, pruning, and using more       │
# │  efficient hardware are being explored to reduce the carbon footprint of     │
# │  LLM training and inference.                                                 │
# │                                                                              │
# │  6. **Interactive AI Assistants:** Advances in conversational agents and     │
# │  interactive AI systems are gaining traction, with LLMs being integrated     │
# │  into virtual assistants, enhancing user interaction through more natural    │
# │  and contextually aware dialogues.                                           │
# │                                                                              │
# │  7. **Open-source LLMs:** The trend towards open-source models is growing,   │
# │  allowing researchers and developers worldwide access to sophisticated       │
# │  LLMs. Projects like Hugging Face's Transformers and EleutherAI's GPT-Neo    │
# │  are important for democratizing LLM technology.                             │
# │                                                                              │
# │  8. **Personalization of AI:** The development of personalized LLMs, which   │
# │  adapt responses based on user preferences and histories, is receiving       │
# │  traction, improving user experience by making AI interactions more          │
# │  relevant and contextual.                                                    │
# │                                                                              │
# │  9. **AI in Education:** LLMs are being increasingly utilized in             │
# │  educational settings, providing personalized tutoring, content generation,  │
# │  and feedback. Their application in creating educational materials is        │
# │  becoming more common, making learning more interactive and tailored.        │
# │                                                                              │
# │  10. **Regulatory Developments:** As LLMs become more integrated into        │
# │  society, regulatory frameworks are evolving to ensure responsible use. The  │
# │  EU AI Act and similar legislation aim to provide guidelines and             │
# │  accountability measures for the deployment of AI technologies, including    │
# │  LLMs.                                                                       │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# 🚀 Crew: crew
# └── 📋 Task: research_task (ID: a6e24e38-a307-45c8-8e28-55624b7d4b4b)
#     Assigned to: AI LLMs Senior Data Researcher
#
#     Status: ✅ Completed
# ╭────────────────────────────── Task Completion ───────────────────────────────╮
# │                                                                              │
# │  Task Completed                                                              │
# │  Name: research_task                                                         │
# │  Agent: AI LLMs Senior Data Researcher                                       │
# │                                                                              │
# │  Tool Args:                                                                  │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: a6e24e38-a307-45c8-8e28-55624b7d4b4b)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 24f50f0a-2ab7-4875-9c10-59e742698c37)
#     Status: Executing Task...
# ╭────────────────────────────── 🤖 Agent Started ──────────────────────────────╮
# │                                                                              │
# │  Agent: AI LLMs Reporting Analyst                                            │
# │                                                                              │
# │  Task: Review the context you got and expand each topic into a full section  │
# │  for a report. Make sure the report is detailed and contains any and all     │
# │  relevant information.                                                       │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: a6e24e38-a307-45c8-8e28-55624b7d4b4b)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 24f50f0a-2ab7-4875-9c10-59e742698c37)
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: a6e24e38-a307-45c8-8e28-55624b7d4b4b)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 24f50f0a-2ab7-4875-9c10-59e742698c37)
#     Status: Executing Task...
# ╭─────────────────────────── ✅ Agent Final Answer ────────────────────────────╮
# │                                                                              │
# │  Agent: AI LLMs Reporting Analyst                                            │
# │                                                                              │
# │  Final Answer:                                                               │
# │  # Comprehensive Report on AI LLMs Trends                                    │
# │                                                                              │
# │  ## 1. Scaling Laws                                                          │
# │  Recent research has provided substantial confirmation regarding the         │
# │  scaling laws pertinent to Large Language Models (LLMs). These laws          │
# │  indicate that as the size of the model and the volume of training data      │
# │  incrementally increase, there is a corresponding improvement in model       │
# │  performance. The implications of this finding are profound, driving the     │
# │  research community towards constructing larger and more sophisticated       │
# │  models. This trend not only enhances the models' capabilities in            │
# │  understanding and generating human-like text but also opens avenues for     │
# │  tackling more complex tasks across a diverse range of applications—from     │
# │  natural language processing (NLP) to advanced decision-making systems.      │
# │  Consequently, organizations are investing in the necessary infrastructure   │
# │  and resources to develop these larger models, promoting a continuous cycle  │
# │  of innovation and performance enhancement within the AI landscape.          │
# │                                                                              │
# │  ## 2. Multimodal LLMs                                                       │
# │  The emergence of multimodal LLMs marks a transformative phase in the        │
# │  interaction between different types of media. These advanced models are     │
# │  capable of processing and generating a wide array of data types, including  │
# │  text, images, and potentially other modalities like audio. Notable          │
# │  examples such as OpenAI's DALL-E and Google’s PaLM illustrate the benefits  │
# │  of this integration, particularly in enhancing creative capabilities.       │
# │  These multimodal approaches allow for richer and more intuitive user        │
# │  experiences, enabling applications like image generation from textual       │
# │  descriptions or understanding content that combines multiple forms of       │
# │  data. By merging various modalities, researchers are unlocking new          │
# │  potentials for creative applications, pushing the boundaries of what AI     │
# │  can achieve in generating holistic content.                                 │
# │                                                                              │
# │  ## 3. Fine-tuning Techniques                                                │
# │  Innovative fine-tuning techniques, such as adapter tuning and prompt        │
# │  tuning, are gaining significant traction within the domain of LLMs. These   │
# │  methods afford a more efficient way of adapting intricate models to         │
# │  specific tasks without necessitating extensive retraining from scratch.     │
# │  Adapter tuning allows researchers to introduce lightweight modules into     │
# │  pre-trained models for particular tasks, thus enhancing versatility while   │
# │  minimizing computational costs. Similarly, prompt tuning substitutes        │
# │  conventional fine-tuning with optimized prompts as input, guiding the       │
# │  model more effectively without altering its fundamental weights. The        │
# │  adoption of these techniques represents a shift towards more flexible and   │
# │  resource-efficient AI systems, facilitating rapid iteration and deployment  │
# │  of models tailored for holistic applications across diverse domains.        │
# │                                                                              │
# │  ## 4. Ethical AI and Bias Mitigation                                        │
# │  As LLMs pervade various sectors, extensive efforts are being made to        │
# │  confront the inherent biases they may exhibit. The growing emphasis on      │
# │  ethical AI has catalyzed the development of frameworks and tools aimed at   │
# │  detecting and mitigating biases in model outputs. Researchers are crafting  │
# │  methodologies that ensure LLMs operate fairly across different              │
# │  demographics, which is essential for responsible AI deployment. By          │
# │  implementing bias detection algorithms and promoting transparency in AI     │
# │  decision-making processes, organizations are fostering a more ethically     │
# │  sound landscape conducive to trust and fairness. This commitment to         │
# │  ethical AI not only serves to protect users but also enhances the validity  │
# │  and reliability of AI outputs across applications.                          │
# │                                                                              │
# │  ## 5. Energy Efficiency                                                     │
# │  Energy consumption has emerged as a critical consideration in the           │
# │  evolution of LLMs, with researchers focusing on strategies to improve       │
# │  energy efficiency in model evaluations. Techniques such as                  │
# │  quantization—reducing the precision of the numerical representations used   │
# │  in models—pruning—removing less important neurons or weights—and employing  │
# │  more efficient hardware all contribute to minimizing the carbon footprint   │
# │  associated with LLM training and inference. By emphasizing these            │
# │  energy-efficient techniques, the AI community is making strides toward      │
# │  sustainability, reaffirming the commitment to developing technologies that  │
# │  are not only powerful but also environmentally responsible.                 │
# │                                                                              │
# │  ## 6. Interactive AI Assistants                                             │
# │  The rise of conversational agents and interactive AI systems is reshaping   │
# │  human-machine interaction. The integration of LLMs into virtual assistants  │
# │  enhances the user's engagement through natural and contextually aware       │
# │  dialogues. These AI-driven assistants are becoming more adept at            │
# │  understanding user intent and generating responses that are relevant and    │
# │  nuanced. As advancements continue to improve the capabilities of these      │
# │  interactive systems, they are increasingly utilized in environments         │
# │  ranging from customer service to education, with the goal of providing a    │
# │  more seamless and intuitive user experience.                                │
# │                                                                              │
# │  ## 7. Open-source LLMs                                                      │
# │  The trend toward open-source LLMs is on the rise, democratizing access to   │
# │  sophisticated AI technologies. Initiatives like Hugging Face's              │
# │  Transformers and EleutherAI's GPT-Neo exemplify the commitment to making    │
# │  advanced models available to researchers and developers globally. This      │
# │  open-source movement encourages collaboration and knowledge-sharing within  │
# │  the AI community, promoting a more innovative ecosystem where individual    │
# │  contributions can significantly impact the capabilities of AI               │
# │  technologies. By lowering barriers to entry, open-source LLMs ensure that   │
# │  diverse perspectives are integrated into AI development, enhancing the      │
# │  model's applicability across various fields.                                │
# │                                                                              │
# │  ## 8. Personalization of AI                                                 │
# │  Personalization in AI represents a significant trend, with LLMs being       │
# │  tailored to adapt responses based on individual user preferences and        │
# │  histories. This personalization is pivotal in enhancing user experience,    │
# │  transforming generic interactions into more relevant and contextualized     │
# │  exchanges. By implementing mechanisms to learn from user engagement,        │
# │  personalized LLMs can deliver targeted content and suggestions, elevating   │
# │  the effectiveness of applications in e-commerce, education, and content     │
# │  generation. Such personalized interactions not only improve user            │
# │  satisfaction but also promote sustained engagement, reflecting a more       │
# │  intelligent understanding of user needs.                                    │
# │                                                                              │
# │  ## 9. AI in Education                                                       │
# │  The application of LLMs in educational contexts is becoming increasingly    │
# │  prevalent, providing innovative solutions for personalized tutoring,        │
# │  content generation, and feedback. These models facilitate the creation of   │
# │  interactive educational materials, making learning experiences tailored     │
# │  and engaging for students. Whether it’s generating quizzes, summarizing     │
# │  complex concepts, or offering real-time assistance, LLMs empower both       │
# │  students and educators to engage in more dynamic and effective learning     │
# │  processes. The ability to personalize educational content contributes to    │
# │  overcoming traditional barriers in education, thereby enhancing             │
# │  accessibility and inclusivity.                                              │
# │                                                                              │
# │  ## 10. Regulatory Developments                                              │
# │  As LLMs become more integrated into everyday life, the corresponding        │
# │  regulatory frameworks are evolving to ensure their responsible deployment.  │
# │  Legislative efforts such as the EU AI Act are aiming to establish           │
# │  guidelines that provide accountability and ethical oversight for the        │
# │  implementation of LLM technology. These regulations focus on issues such    │
# │  as data privacy, fairness, transparency, and security, paving the way for   │
# │  responsible AI use across industries. As these frameworks take shape, they  │
# │  will guide organizations in developing AI technologies that not only drive  │
# │  innovation but also adhere to societal norms and ethical standards.         │
# │                                                                              │
# │  In conclusion, the advancements in AI LLMs are substantial and              │
# │  multifaceted, impacting various sectors and practices. As we continue to    │
# │  explore these trends, the collaboration between technology and ethical      │
# │  considerations will be crucial for fostering a responsible AI ecosystem.    │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: a6e24e38-a307-45c8-8e28-55624b7d4b4b)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 24f50f0a-2ab7-4875-9c10-59e742698c37)
#     Assigned to: AI LLMs Reporting Analyst
#
#     Status: ✅ Completed
# ╭────────────────────────────── Task Completion ───────────────────────────────╮
# │                                                                              │
# │  Task Completed                                                              │
# │  Name: reporting_task                                                        │
# │  Agent: AI LLMs Reporting Analyst                                            │
# │                                                                              │
# │  Tool Args:                                                                  │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────── Crew Completion ───────────────────────────────╮
# │                                                                              │
# │  Crew Execution Completed                                                    │
# │  Name: crew                                                                  │
# │  ID: fcab55cc-1ed8-4841-95c0-58bd668e4185                                    │
# │  Tool Args:                                                                  │
# │  Final Output: # Comprehensive Report on AI LLMs Trends                      │
# │                                                                              │
# │  ## 1. Scaling Laws                                                          │
# │  Recent research has provided substantial confirmation regarding the         │
# │  scaling laws pertinent to Large Language Models (LLMs). These laws          │
# │  indicate that as the size of the model and the volume of training data      │
# │  incrementally increase, there is a corresponding improvement in model       │
# │  performance. The implications of this finding are profound, driving the     │
# │  research community towards constructing larger and more sophisticated       │
# │  models. This trend not only enhances the models' capabilities in            │
# │  understanding and generating human-like text but also opens avenues for     │
# │  tackling more complex tasks across a diverse range of applications—from     │
# │  natural language processing (NLP) to advanced decision-making systems.      │
# │  Consequently, organizations are investing in the necessary infrastructure   │
# │  and resources to develop these larger models, promoting a continuous cycle  │
# │  of innovation and performance enhancement within the AI landscape.          │
# │                                                                              │
# │  ## 2. Multimodal LLMs                                                       │
# │  The emergence of multimodal LLMs marks a transformative phase in the        │
# │  interaction between different types of media. These advanced models are     │
# │  capable of processing and generating a wide array of data types, including  │
# │  text, images, and potentially other modalities like audio. Notable          │
# │  examples such as OpenAI's DALL-E and Google’s PaLM illustrate the benefits  │
# │  of this integration, particularly in enhancing creative capabilities.       │
# │  These multimodal approaches allow for richer and more intuitive user        │
# │  experiences, enabling applications like image generation from textual       │
# │  descriptions or understanding content that combines multiple forms of       │
# │  data. By merging various modalities, researchers are unlocking new          │
# │  potentials for creative applications, pushing the boundaries of what AI     │
# │  can achieve in generating holistic content.                                 │
# │                                                                              │
# │  ## 3. Fine-tuning Techniques                                                │
# │  Innovative fine-tuning techniques, such as adapter tuning and prompt        │
# │  tuning, are gaining significant traction within the domain of LLMs. These   │
# │  methods afford a more efficient way of adapting intricate models to         │
# │  specific tasks without necessitating extensive retraining from scratch.     │
# │  Adapter tuning allows researchers to introduce lightweight modules into     │
# │  pre-trained models for particular tasks, thus enhancing versatility while   │
# │  minimizing computational costs. Similarly, prompt tuning substitutes        │
# │  conventional fine-tuning with optimized prompts as input, guiding the       │
# │  model more effectively without altering its fundamental weights. The        │
# │  adoption of these techniques represents a shift towards more flexible and   │
# │  resource-efficient AI systems, facilitating rapid iteration and deployment  │
# │  of models tailored for holistic applications across diverse domains.        │
# │                                                                              │
# │  ## 4. Ethical AI and Bias Mitigation                                        │
# │  As LLMs pervade various sectors, extensive efforts are being made to        │
# │  confront the inherent biases they may exhibit. The growing emphasis on      │
# │  ethical AI has catalyzed the development of frameworks and tools aimed at   │
# │  detecting and mitigating biases in model outputs. Researchers are crafting  │
# │  methodologies that ensure LLMs operate fairly across different              │
# │  demographics, which is essential for responsible AI deployment. By          │
# │  implementing bias detection algorithms and promoting transparency in AI     │
# │  decision-making processes, organizations are fostering a more ethically     │
# │  sound landscape conducive to trust and fairness. This commitment to         │
# │  ethical AI not only serves to protect users but also enhances the validity  │
# │  and reliability of AI outputs across applications.                          │
# │                                                                              │
# │  ## 5. Energy Efficiency                                                     │
# │  Energy consumption has emerged as a critical consideration in the           │
# │  evolution of LLMs, with researchers focusing on strategies to improve       │
# │  energy efficiency in model evaluations. Techniques such as                  │
# │  quantization—reducing the precision of the numerical representations used   │
# │  in models—pruning—removing less important neurons or weights—and employing  │
# │  more efficient hardware all contribute to minimizing the carbon footprint   │
# │  associated with LLM training and inference. By emphasizing these            │
# │  energy-efficient techniques, the AI community is making strides toward      │
# │  sustainability, reaffirming the commitment to developing technologies that  │
# │  are not only powerful but also environmentally responsible.                 │
# │                                                                              │
# │  ## 6. Interactive AI Assistants                                             │
# │  The rise of conversational agents and interactive AI systems is reshaping   │
# │  human-machine interaction. The integration of LLMs into virtual assistants  │
# │  enhances the user's engagement through natural and contextually aware       │
# │  dialogues. These AI-driven assistants are becoming more adept at            │
# │  understanding user intent and generating responses that are relevant and    │
# │  nuanced. As advancements continue to improve the capabilities of these      │
# │  interactive systems, they are increasingly utilized in environments         │
# │  ranging from customer service to education, with the goal of providing a    │
# │  more seamless and intuitive user experience.                                │
# │                                                                              │
# │  ## 7. Open-source LLMs                                                      │
# │  The trend toward open-source LLMs is on the rise, democratizing access to   │
# │  sophisticated AI technologies. Initiatives like Hugging Face's              │
# │  Transformers and EleutherAI's GPT-Neo exemplify the commitment to making    │
# │  advanced models available to researchers and developers globally. This      │
# │  open-source movement encourages collaboration and knowledge-sharing within  │
# │  the AI community, promoting a more innovative ecosystem where individual    │
# │  contributions can significantly impact the capabilities of AI               │
# │  technologies. By lowering barriers to entry, open-source LLMs ensure that   │
# │  diverse perspectives are integrated into AI development, enhancing the      │
# │  model's applicability across various fields.                                │
# │                                                                              │
# │  ## 8. Personalization of AI                                                 │
# │  Personalization in AI represents a significant trend, with LLMs being       │
# │  tailored to adapt responses based on individual user preferences and        │
# │  histories. This personalization is pivotal in enhancing user experience,    │
# │  transforming generic interactions into more relevant and contextualized     │
# │  exchanges. By implementing mechanisms to learn from user engagement,        │
# │  personalized LLMs can deliver targeted content and suggestions, elevating   │
# │  the effectiveness of applications in e-commerce, education, and content     │
# │  generation. Such personalized interactions not only improve user            │
# │  satisfaction but also promote sustained engagement, reflecting a more       │
# │  intelligent understanding of user needs.                                    │
# │                                                                              │
# │  ## 9. AI in Education                                                       │
# │  The application of LLMs in educational contexts is becoming increasingly    │
# │  prevalent, providing innovative solutions for personalized tutoring,        │
# │  content generation, and feedback. These models facilitate the creation of   │
# │  interactive educational materials, making learning experiences tailored     │
# │  and engaging for students. Whether it’s generating quizzes, summarizing     │
# │  complex concepts, or offering real-time assistance, LLMs empower both       │
# │  students and educators to engage in more dynamic and effective learning     │
# │  processes. The ability to personalize educational content contributes to    │
# │  overcoming traditional barriers in education, thereby enhancing             │
# │  accessibility and inclusivity.                                              │
# │                                                                              │
# │  ## 10. Regulatory Developments                                              │
# │  As LLMs become more integrated into everyday life, the corresponding        │
# │  regulatory frameworks are evolving to ensure their responsible deployment.  │
# │  Legislative efforts such as the EU AI Act are aiming to establish           │
# │  guidelines that provide accountability and ethical oversight for the        │
# │  implementation of LLM technology. These regulations focus on issues such    │
# │  as data privacy, fairness, transparency, and security, paving the way for   │
# │  responsible AI use across industries. As these frameworks take shape, they  │
# │  will guide organizations in developing AI technologies that not only drive  │
# │  innovation but also adhere to societal norms and ethical standards.         │
# │                                                                              │
# │  In conclusion, the advancements in AI LLMs are substantial and              │
# │  multifaceted, impacting various sectors and practices. As we continue to    │
# │  explore these trends, the collaboration between technology and ethical      │
# │  considerations will be crucial for fostering a responsible AI ecosystem.    │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
#
#
# ╭────────────────────────────── Execution Traces ──────────────────────────────╮
# │                                                                              │
# │  🔍 Detailed execution traces are available!                                 │
# │                                                                              │
# │  View insights including:                                                    │
# │    • Agent decision-making process                                           │
# │    • Task execution flow and timing                                          │
# │    • Tool usage details                                                      │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# Would you like to view your execution traces? [y/N] (20s timeout):

# %% [markdown]
# ## Flows CLI - Command Line Interface

# %%
! crewai create flow new_flow
# Out:
# Creating flow new_flow...
# Flow new_flow created successfully!

# %%
! ls -1 new_flow
# Out:
# README.md
# pyproject.toml
# src
# tests

# %%
! ls -1 new_flow/src/new_flow/
# Out:
# __init__.py
# crews
# main.py
# tools
